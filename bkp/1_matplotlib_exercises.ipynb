# %% [markdown]
# # Matplotlib Exercises
#
# **NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP.**
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Note:** Import `matplotlib.pyplot` as plt and set `%matplotlib inline` if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
#
# Follow along with these steps:
# 1. Create a figure object called fig using `plt.figure()`
# 1. Use `add_axes` to add an axis to the figure canvas at [0,0,1,1]. Call this new axis `ax`.
# 1. Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title("ax")
ax.plot(x,y)
fig.show
# Out:
# <bound method Figure.show of <Figure size 432x288 with 1 Axes>>

# %% [markdown]
# ## Exercise 2
# Create a figure object and put two axes on it, `ax1` and `ax2`. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.

# %% [markdown]
# Now plot (x,y) on both axes. And call your figure object to show it.

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])
ax.plot(x,y)
ax2.plot(x,y)
fig.show
# Out:
# <bound method Figure.show of <Figure size 432x288 with 2 Axes>>

# %% [markdown]
# ## Exercise 3
#
# Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]

# %% [markdown]
# Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])
ax.plot(x,y,z)
ax2.plot(x,y,z)
fig.show
# Out:
# <bound method Figure.show of <Figure size 432x288 with 2 Axes>>

# %% [markdown]
# ## Exercise 4
#
# Use `plt.subplots(nrows=1, ncols=2)` to create the plot below.

# %% [markdown]
# Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style

# %%
fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(20,10))
ax[0].plot(x,y, linewidth=10)
ax[1].plot(x,z)

fig.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-171-37072b23d9df> in <module>
# ----> 1 fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(20,10),projection='polar')
#       2 ax[0].plot(x,y, linewidth=10)
#       3 ax[1].plot(x,z)
#       4
#       5 fig.show
#
# /usr/local/lib/python3.9/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# /usr/local/lib/python3.9/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1285
#    1286     """
# -> 1287     fig = figure(**fig_kw)
#    1288     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1289                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# /usr/local/lib/python3.9/site-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     685             dpi = 72
#     686
# --> 687         figManager = new_figure_manager(num, figsize=figsize,
#     688                                         dpi=dpi,
#     689                                         facecolor=facecolor,
#
# /usr/local/lib/python3.9/site-packages/matplotlib/pyplot.py in new_figure_manager(*args, **kwargs)
#     313     """Create a new figure manager instance."""
#     314     _warn_if_gui_out_of_main_thread()
# --> 315     return _backend_mod.new_figure_manager(*args, **kwargs)
#     316
#     317
#
# /usr/local/lib/python3.9/site-packages/matplotlib/backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3491         from matplotlib.figure import Figure
#    3492         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3493         fig = fig_cls(*args, **kwargs)
#    3494         return cls.new_figure_manager_given_figure(num, fig)
#    3495
#
# TypeError: __init__() got an unexpected keyword argument 'projection'

# %% [markdown]
# See if you can resize the plot by adding the `figsize()` argument in `plt.subplots()` are copying and pasting your previous code.
